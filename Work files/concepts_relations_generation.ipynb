# %%
import pandas as pd
import nltk

# %%
file = 'TRF_ISO_12100.xlsx'
df = pd.read_excel(file)
df.head()
# Out:
#    Clause Question number                                             Points  \
# 0     4.0             NaN    Strategy for risk assessment and risk reduction
# 1     NaN                  To implement risk assessment and risk reductio...
# 2     NaN              a)  determine the limits of the machinery, which i...
# 3     NaN              b)  identify the hazards and associated hazardous ...
# 4     NaN              c)  estimate the risk for each identified hazard a...
#
#                                             Concepts  Relations
# 0  ['Strategy', 'risk', 'assessment', 'risk', 're...        NaN
# 1  ['risk', 'assessment', 'risk', 'reduction', 'd...        NaN
# 2  ['limits', 'machinery', 'use', 'misuse', 'ther...        NaN
# 3                          ['hazards', 'situations']        NaN
# 4        ['estimate', 'risk', 'hazard', 'situation']        NaN

# %%
noun_list = []
verb_list = []
for i in range (len(df)):
    lines = df.iloc[i,2]
    sentences = nltk.sent_tokenize(lines) #tokenize sentences
    nouns = []
    verbs = []

    for sentence in sentences:
        for word,pos in nltk.pos_tag(nltk.word_tokenize(str(sentence))):
            if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS'):
                nouns.append(word)
            if (pos == 'VP' or pos == 'VBD' or pos == 'VBG' or pos == 'VBN' or pos == 'VBP' or pos == 'VBZ'):
                verbs.append(word)
    noun_list.append(nouns)
    verb_list.append(verbs)
df['Concepts'] = noun_list
df['Relations'] = verb_list
df.head()
# Out:
#    Clause Question number                                             Points  \
# 0     4.0             NaN    Strategy for risk assessment and risk reduction
# 1     NaN                  To implement risk assessment and risk reductio...
# 2     NaN              a)  determine the limits of the machinery, which i...
# 3     NaN              b)  identify the hazards and associated hazardous ...
# 4     NaN              c)  estimate the risk for each identified hazard a...
#
#                                             Concepts     Relations
# 0      [Strategy, risk, assessment, risk, reduction]            []
# 1  [risk, assessment, risk, reduction, designer, ...       [given]
# 2          [limits, machinery, use, misuse, thereof]     [include]
# 3                              [hazards, situations]  [associated]
# 4                [estimate, risk, hazard, situation]  [identified]

# %%
df.to_excel(file, index=False)
