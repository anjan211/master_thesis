# %%
import pandas as pd
import stanza
from stanza.server import CoreNLPClient

# %%
file = 'TRF_ISO_12100.xlsx'
df = pd.read_excel(file)
df.head()
# Out:
#    Clause Question number                                             Points  \
# 0     4.0             NaN    Strategy for risk assessment and risk reduction
# 1     NaN                  To implement risk assessment and risk reductio...
# 2     NaN              a)  determine the limits of the machinery, which i...
# 3     NaN              b)  identify the hazards and associated hazardous ...
# 4     NaN              c)  estimate the risk for each identified hazard a...
#
#                                             Concepts       Relations
# 0  ['Strategy', 'risk', 'assessment', 'risk', 're...              []
# 1  ['risk', 'assessment', 'risk', 'reduction', 'd...       ['given']
# 2  ['limits', 'machinery', 'use', 'misuse', 'ther...     ['include']
# 3                          ['hazards', 'situations']  ['associated']
# 4        ['estimate', 'risk', 'hazard', 'situation']  ['identified']

# %%
triples_list = []
with CoreNLPClient(annotators=['openie'], be_quiet=False, endpoint='http://localhost:8882') as client:
    for i in range (len(df)):
        lines = df.iloc[i,2]
        document = client.annotate(lines, output_format='json')
        triples = []
        for sentence in document['sentences']:
            for triple in sentence['openie']:
                triples.append({
                'subject': triple['subject'],
                'relation': triple['relation'],
                'object': triple['object']
                })
        triples_list.append(triples)
df['Triples'] = triples_list
df.head()
# Out:
# 2022-12-19 03:52:26 INFO: Writing properties to tmp file: corenlp_server-3064b7e87a1e404e.props
# 2022-12-19 03:52:26 INFO: Starting server with command: java -Xmx5G -cp C:\Users\chatt\stanza_corenlp\* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 8882 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet False -serverProperties corenlp_server-3064b7e87a1e404e.props -annotators openie -preload -outputFormat serialized
#    Clause Question number                                             Points  \
# 0     4.0             NaN    Strategy for risk assessment and risk reduction
# 1     NaN                  To implement risk assessment and risk reductio...
# 2     NaN              a)  determine the limits of the machinery, which i...
# 3     NaN              b)  identify the hazards and associated hazardous ...
# 4     NaN              c)  estimate the risk for each identified hazard a...
#
#                                             Concepts       Relations  \
# ...

# %%
df.to_excel(file, index=False)
